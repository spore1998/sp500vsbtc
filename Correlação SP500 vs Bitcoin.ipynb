# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
btc = pd.read_csv('btc.csv',index_col='Date',parse_dates=True, decimal='.', thousands=',')
btc = btc['Price']

spy = pd.read_csv('spy.csv',index_col='Date',parse_dates=True, decimal='.', thousands=',')
spy = spy['Price']
btc
# Out:
# Date
# 2020-03-15    5344.9
# 2020-03-14    5218.2
# 2020-03-13    5625.4
# 2020-03-12    4927.0
# 2020-03-11    7969.6
#                ...
# 2012-02-06       5.4
# 2012-02-05       5.7
# 2012-02-04       5.9
# 2012-02-03       6.0
# 2012-02-02       6.1
# Name: Price, Length: 2948, dtype: float64

# %%
teste = pd.concat([btc,spy],axis=1).dropna()
teste.columns = ['btc','spy']

teste1 = teste.pct_change(1)
teste1
# Out:
#                  btc       spy
# Date
# 2012-02-02       NaN       NaN
# 2012-02-03 -0.016393  0.014605
# 2012-02-06 -0.100000 -0.000424
# 2012-02-07  0.055556  0.002023
# 2012-02-08 -0.017544  0.002160
# ...              ...       ...
# 2020-03-09 -0.132159 -0.075970
# 2020-03-10 -0.006715  0.049396
# 2020-03-11  0.007051 -0.048868
# 2020-03-12 -0.381776 -0.095113
# 2020-03-13  0.141750  0.092871
#
# [2031 rows x 2 columns]

# %%
teste1.plot.scatter(x='btc', y='spy', c='blue',s=150,alpha=0.3,figsize=(20,10),label='1 dia')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='r')

# %%
teste1.corr()
# Out:
#           btc       spy
# btc  1.000000  0.055089
# spy  0.055089  1.000000

# %%
teste30 = teste.pct_change(30)
teste30
# Out:
#                  btc       spy
# Date
# 2012-02-02       NaN       NaN
# 2012-02-03       NaN       NaN
# 2012-02-06       NaN       NaN
# 2012-02-07       NaN       NaN
# 2012-02-08       NaN       NaN
# ...              ...       ...
# 2020-03-09 -0.056801 -0.166565
# 2020-03-10 -0.112006 -0.111418
# 2020-03-11 -0.151602 -0.163254
# 2020-03-12 -0.470454 -0.242182
# 2020-03-13 -0.408643 -0.174391
#
# [2031 rows x 2 columns]

# %%
teste30.plot.scatter(x='btc', y='spy', c='green',s=150,alpha=0.3,figsize=(20,10),label='30 dias')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='r')

# %%
teste30.corr()
# Out:
#           btc       spy
# btc  1.000000  0.209903
# spy  0.209903  1.000000

# %%
teste365 = teste.pct_change(365)
teste365x2 = teste.pct_change(365*2)
teste365x4 = teste.pct_change(365*4)

# %%
teste365.plot.scatter(x='btc', y='spy', c='green',s=150,alpha=0.3,figsize=(20,10),label='365 dias')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='r')


teste365x2.plot.scatter(x='btc', y='spy', c='blue',s=150,alpha=0.3,figsize=(20,10),label='2 anos')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='r')


teste365x4.plot.scatter(x='btc', y='spy', c='orange',s=150,alpha=0.3,figsize=(20,10),label='4 anos')
plt.axvline(x=0, color='r')
plt.axhline(y=0, color='r')

# %%
teste365.corr()
# Out:
#           btc       spy
# btc  1.000000  0.594163
# spy  0.594163  1.000000

# %%
teste365x2.corr()
# Out:
#           btc       spy
# btc  1.000000  0.571845
# spy  0.571845  1.000000

# %%
teste365x4.corr()
# Out:
#           btc       spy
# btc  1.000000  0.665821
# spy  0.665821  1.000000
